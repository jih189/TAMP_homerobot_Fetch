# %%
import numpy as np

npz_file = '/root/catkin_ws/src/jiaming_manipulation/task_planner/mesh_dir/door_v3.npz'
data = np.load(npz_file)

for key in data.files:
    print "Key: %s" % key
    matrix = data[key]
    print "Matrix associated with key '%s':" % key
    print matrix
    print "-" * 50
# Out:
# Key: arr_60
# Matrix associated with key 'arr_60':
# [[-2.81566408e-18 -9.99919593e-01 -1.26806237e-02  5.72701275e-04]
#  [-2.22026751e-16  1.26806237e-02 -9.99919593e-01 -1.22395630e-01]
#  [ 1.00000000e+00  0.00000000e+00 -2.22044605e-16  1.58945913e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# --------------------------------------------------
# Key: arr_61
# Matrix associated with key 'arr_61':
# [[-2.81566408e-18  9.99919593e-01  1.26806237e-02  5.72701275e-04]
#  [-2.22026751e-16 -1.26806237e-02  9.99919593e-01 -1.22395630e-01]
#  [ 1.00000000e+00 -2.71926227e-32  2.22044605e-16  1.58945913e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# --------------------------------------------------
# Key: arr_62
# Matrix associated with key 'arr_62':
# [[ 0.01268062 -0.99991959  0.         -0.00157553]
#  [ 0.99991959  0.01268062  0.         -0.29179404]
#  [ 0.          0.          1.          0.03352694]
# ...

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 加载npz文件
npz_file = '/root/catkin_ws/src/jiaming_manipulation/task_planner/mesh_dir/door_v3.npz'
data = np.load(npz_file)

# 提取每个矩阵的平移部分作为点坐标
points = np.array([data[key][:3, 3] for key in data.files])

# 创建3D图形
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制点
ax.scatter(points[:, 0], points[:, 1], points[:, 2])

# 设置坐标轴标签
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# 显示图形
plt.show()
